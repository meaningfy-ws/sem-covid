# %% [markdown]
# # EDA categorical on PWDB

# %% [markdown]
# ## Import libraries

# %%
import pathlib as path
import pandas as pd
import plotly.express as px
from collections import  Counter
from IPython.display import display, Markdown
import statsmodels.api as sm
import numpy as np
import scipy.stats as stats

from tqdm import tqdm

# %% [markdown]
# ## Define constants

# %%
LOCAL_FOLDER = path.Path("/mnt/c/Users/Professional/Desktop/Works/MEANING/Sem-Covid19/data/")

SERVER_FOLDER  = path.Path("/home/jovyan/data/")

WORK_DIR = ""
if SERVER_FOLDER.exists():
    WORK_DIR = SERVER_FOLDER
    print("Work with distant directory.")
elif LOCAL_FOLDER.exists():
    WORK_DIR = LOCAL_FOLDER
    print("Work with local directory.")
else:
    print("ERROR: Invalid directory!")
# Out:
# Work with distant directory.

# %%
SRC_JSON_FILE_NAME = "covid19db.json"
SRC_PICKLE_FILE_NAME = "pwdb_prepared.pkl"

SRC_FILE_NAME = SRC_JSON_FILE_NAME

SRC_FILE_PATH = WORK_DIR / SRC_FILE_NAME

CATEGORICAL_COLUMNS = ['country', 'category', 'subcategory','actors', 'target_groups','Businesses','Citizens','Workers', 'funding']

BUSINESSES ={'Companies providing essential services', 'Contractors of a company', 'Larger corporations', 'One person or microenterprises', 'Other businesses', 'SMEs', 'Sector specific set of companies', 'Solo-self-employed', 'Start-ups'}

CITIZENS ={'Children (minors)', 'Disabled', 'Migrants', 'Older citizens', 'Other groups of citizens', 'Parents', 'People in care facilities', 'Refugees', 'Single parents', 'The COVID-19 risk group', 'Women', 'Youth (18-25)'}

WORKERS = {'Cross-border commuters', 'Disabled workers', 'Employees in standard employment', 'Female workers', 'Migrants in employment', 'Older people in employment (aged 55+)', 'Other groups of workers', 'Parents in employment', 'Particular professions', 'Platform workers', 'Posted workers', 'Refugees in employment', 'Seasonal workers', 'Self-employed', 'Single parents in employment', 'The COVID-19 risk group at the workplace', 'Undeclared workers', 'Unemployed', 'Workers in care facilities', 'Workers in essential services', 'Workers in non-standard forms of employment', 'Youth (18-25) in employment'}

# %% [markdown]
# ## Load PWDB dataset

# %%
if SRC_FILE_PATH.exists():
    df = pd.read_json(SRC_FILE_PATH)
    #df = pd.read_pickle(SRC_FILE_PATH)
else:
    print("Source path is invalid!")

# %% [markdown]
# ## Function to transform target_group

# %%
def target_group_refactoring(pwdb_dataframe: pd.DataFrame,target_group_column_name: str = 'target_groups') -> pd.DataFrame:
    """
        The target group available in the original dataset is very granular. For the purpose of this exercise
        we would benefit from aggregating the target groups into a more generic sets. As a result we will obtain
        target groups on two levels: L1, L2.
        L1: workers, businesses, citizens
        L2: the original set of categories

        :return: the given dataset with an extra column containing the aggregated (L1) values
    """
    new_columns = {'Businesses':BUSINESSES,'Citizens':CITIZENS,'Workers':WORKERS}
    refactored_pwdb_df = pwdb_dataframe[target_group_column_name]
    for column,class_set in new_columns.items():
         pwdb_dataframe[column] = refactored_pwdb_df.apply(lambda x: any(item in class_set for item in x))
         pwdb_dataframe[column].replace({True: column+"_True", False: column+"_False"}, inplace=True)
    return pwdb_dataframe

# %% [markdown]
# ## Transform DataFrame to target_group with L1/L2

# %%
df = target_group_refactoring(df)

# %% [markdown]
# ## Function for plot bar chart on observations

# %%
def plot_bar_chart(observations: pd.DataFrame,chart_title: str):
    columns = observations.columns
    return px.bar(observations,x=columns[1],y=columns[0],title=chart_title)

# %% [markdown]
# ## Function for plot pie chart on observations

# %%
def plot_pie_chart(observations: pd.DataFrame,chart_title: str):
    columns = observations.columns
    return px.pie(observations,values=columns[1],names=columns[0],title=chart_title )

# %% [markdown]
# ## Function for making observations on categorical data

# %%
def calc_freq_categorical_data(data : pd.Series,title : str ,relative : bool = False ):
    observation_type_name = 'Absolute freq' if not relative else 'Relative freq'
    data.dropna(inplace=True)
    observation = pd.DataFrame(Counter(data).most_common(),columns=[title,observation_type_name])
    if relative:
        observation[observation_type_name]/=observation[observation_type_name].sum()/100
        observation[observation_type_name]=round(observation[observation_type_name],2)
    return observation

# %% [markdown]
# ## Function for making observations on missing data

# %%
def calc_freq_missing_data(data : pd.DataFrame,relative : bool = False):
    observation_type_name = 'Absolute freq' if not relative else 'Relative freq'
    columns = data.columns
    tmp = pd.Series(dtype=object)
    for column in columns:
        series_tmp = data[column].explode()
        tmp[column]= series_tmp.isnull().sum()
        if relative:
            tmp[column]/=series_tmp.size/100
            tmp[column]=round(tmp[column],2)
    observation = pd.DataFrame(tmp[tmp>0] ,columns=[observation_type_name])
    observation.reset_index(inplace=True)
    return observation

# %% [markdown]
# ## EDA on categorical data from loaded dataset

# %%
def fast_categorical_analyze(data : pd.DataFrame,data_title : str = 'Unknown'):
    results = {}
    abs_miss_obs = calc_freq_missing_data(data)
    display(abs_miss_obs)

    if abs_miss_obs.size>0:
        plot_pie_chart(abs_miss_obs,data_title+' missing values').show()
    data = data[CATEGORICAL_COLUMNS]
    for column_name in data.columns:
        data_column = data[column_name].explode()
        try:
            rel_obs = calc_freq_categorical_data(data_column,column_name,True)
            results[column_name] = rel_obs
            rel_obs = rel_obs.head(10)
            display(rel_obs)
            plot_bar_chart(rel_obs,column_name).show()
            plot_pie_chart(rel_obs,column_name).show()
        except:
            print('Observation on [',column_name,'] fault!')
            print('Check if column [',column_name,'] have compatible type!')
    return results

eda_result = fast_categorical_analyze(df,"PWDB Dataset")
# Out:
#                  index  Absolute freq
# 0             end_date            509
# 1  social_partner_form           1171
# 2  social_partner_role           1171
# 3        target_groups            303
# 4              sectors            729
# 5          occupations           1056
# 6              sources              1
# <div>                            <div id="1b6e0170-731c-4576-81e3-0b45aa2bf834" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b6e0170-731c-4576-81e3-0b45aa2bf834")) {                    Plotly.newPlot(                        "1b6e0170-731c-4576-81e3-0b45aa2bf834",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "index=%{label}<br>Absolute freq=%{value}<extra></extra>", "labels": ["end_date", "social_partner_form", "social_partner_role", "target_groups", "sectors", "occupations", "sources"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [509, 1171, 1171, 303, 729, 1056, 1]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin ...
#      country  Relative freq
# 0      Spain           6.66
# 1      Italy           5.12
# 2     Greece           5.04
# 3    Germany           4.95
# 4    Austria           4.87
# 5   Portugal           4.53
# 6     France           4.01
# 7    Croatia           3.67
# 8  Lithuania           3.50
# 9     Norway           3.50
# <div>                            <div id="3d2975f4-08b1-4477-8e0c-7f03ad773023" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d2975f4-08b1-4477-8e0c-7f03ad773023")) {                    Plotly.newPlot(                        "3d2975f4-08b1-4477-8e0c-7f03ad773023",                        [{"alignmentgroup": "True", "hovertemplate": "Relative freq=%{x}<br>country=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "h", "showlegend": false, "textposition": "auto", "type": "bar", "x": [6.66, 5.12, 5.04, 4.95, 4.87, 4.53, 4.01, 3.67, 3.5, 3.5], "xaxis": "x", "y": ["Spain", "Italy", "Greece", "Germany", "Austria", "Portugal", "France", "Croatia", "Lithuania", "Norway"], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": ...
# <div>                            <div id="661b5ccd-fbfe-4be7-94c1-fcba041ed232" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("661b5ccd-fbfe-4be7-94c1-fcba041ed232")) {                    Plotly.newPlot(                        "661b5ccd-fbfe-4be7-94c1-fcba041ed232",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "country=%{label}<br>Relative freq=%{value}<extra></extra>", "labels": ["Spain", "Italy", "Greece", "Germany", "Austria", "Portugal", "France", "Croatia", "Lithuania", "Norway"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [6.66, 5.12, 5.04, 4.95, 4.87, 4.53, 4.01, 3.67, 3.5, 3.5]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "p ...
#                                             category  Relative freq
# 0               Supporting businesses to stay afloat          28.10
# 1     Protection of workers, adaptation of workplace          14.35
# 2           Income protection beyond short-time work          12.21
# 3  Promoting the economic, labour market and soci...          10.16
# 4  Ensuring business continuity and support for e...           9.65
# 5                Employment protection and retention           9.39
# 6                Measures to prevent social hardship           7.09
# 7               Reorientation of business activities           5.72
# 8        Supporting businesses to get back to normal           3.33
# <div>                            <div id="1c3a9097-ea56-4857-b4ff-221dd2b1e788" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c3a9097-ea56-4857-b4ff-221dd2b1e788")) {                    Plotly.newPlot(                        "1c3a9097-ea56-4857-b4ff-221dd2b1e788",                        [{"alignmentgroup": "True", "hovertemplate": "Relative freq=%{x}<br>category=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "h", "showlegend": false, "textposition": "auto", "type": "bar", "x": [28.1, 14.35, 12.21, 10.16, 9.65, 9.39, 7.09, 5.72, 3.33], "xaxis": "x", "y": ["Supporting businesses to stay afloat", "Protection of workers, adaptation of workplace", "Income protection beyond short-time work", "Promoting the economic, labour market and social recovery", "Ensuring business continuity and support for essential services", "Employment protection and retention", "Measures to prevent social hardship", "Reorientation of business activities", "Supporting businesses to get back to normal"], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#720 ...
# <div>                            <div id="876bc7b7-1cd3-4821-82c3-8090a0f583ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("876bc7b7-1cd3-4821-82c3-8090a0f583ab")) {                    Plotly.newPlot(                        "876bc7b7-1cd3-4821-82c3-8090a0f583ab",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "category=%{label}<br>Relative freq=%{value}<extra></extra>", "labels": ["Supporting businesses to stay afloat", "Protection of workers, adaptation of workplace", "Income protection beyond short-time work", "Promoting the economic, labour market and social recovery", "Ensuring business continuity and support for essential services", "Employment protection and retention", "Measures to prevent social hardship", "Reorientation of business activities", "Supporting businesses to get back to normal"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [28.1, 14.35, 12.21, 10.16, 9.65, 9.39, 7.09, 5.72, 3.33]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0. ...
#                                          subcategory  Relative freq
# 0                 Direct subsidies (full or partial)          12.89
# 1                                  Access to finance           7.60
# 2  Income support for people in employment (e.g. ...           7.26
# 3                                              Other           5.81
# 4                Deferral of payments or liabilities           5.55
# 5                     Occupational health and safety           4.95
# 6  Extensions of  income support to workers not c...           4.78
# 7                    Change of production/innovation           4.61
# 8  Active labour market policies, incl. subsidise...           4.61
# 9           Teleworking arrangements, remote working           4.36
# <div>                            <div id="946731a4-f3e6-4764-886f-a2c631629db3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("946731a4-f3e6-4764-886f-a2c631629db3")) {                    Plotly.newPlot(                        "946731a4-f3e6-4764-886f-a2c631629db3",                        [{"alignmentgroup": "True", "hovertemplate": "Relative freq=%{x}<br>subcategory=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "h", "showlegend": false, "textposition": "auto", "type": "bar", "x": [12.89, 7.6, 7.26, 5.81, 5.55, 4.95, 4.78, 4.61, 4.61, 4.36], "xaxis": "x", "y": ["Direct subsidies (full or partial)", "Access to finance", "Income support for people in employment (e.g. short-time work)", "Other", "Deferral of payments or liabilities", "Occupational health and safety", "Extensions of  income support to workers not covered by any kind of protection scheme", "Change of production/innovation", "Active labour market policies, incl. subsidised job creation", "Teleworking arrangements, remote working"], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.22222 ...
# <div>                            <div id="e595f5ec-c582-4e35-a915-f1b7140afa6f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e595f5ec-c582-4e35-a915-f1b7140afa6f")) {                    Plotly.newPlot(                        "e595f5ec-c582-4e35-a915-f1b7140afa6f",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "subcategory=%{label}<br>Relative freq=%{value}<extra></extra>", "labels": ["Direct subsidies (full or partial)", "Access to finance", "Income support for people in employment (e.g. short-time work)", "Other", "Deferral of payments or liabilities", "Occupational health and safety", "Extensions of  income support to workers not covered by any kind of protection scheme", "Change of production/innovation", "Active labour market policies, incl. subsidised job creation", "Teleworking arrangements, remote working"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [12.89, 7.6, 7.26, 5.81, 5.55, 4.95, 4.78, 4.61, 4.61, 4.36]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.555555555555555 ...
#                              actors  Relative freq
# 0               National government          38.36
# 1               Company / Companies          18.97
# 2                      Trade unions           7.90
# 3          Employers' organisations           7.29
# 4           Social partners jointly           6.45
# 5       Local / regional government           4.91
# 6         Public employment service           4.53
# 7                  Social insurance           3.83
# 8   Other social actors (e.g. NGOs)           3.36
# 9  Public support service providers           2.57
# <div>                            <div id="3f47f9b0-be12-4b26-9bd0-ef53a5171f05" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f47f9b0-be12-4b26-9bd0-ef53a5171f05")) {                    Plotly.newPlot(                        "3f47f9b0-be12-4b26-9bd0-ef53a5171f05",                        [{"alignmentgroup": "True", "hovertemplate": "Relative freq=%{x}<br>actors=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "h", "showlegend": false, "textposition": "auto", "type": "bar", "x": [38.36, 18.97, 7.9, 7.29, 6.45, 4.91, 4.53, 3.83, 3.36, 2.57], "xaxis": "x", "y": ["National government", "Company / Companies", "Trade unions", "Employers' organisations", "Social partners jointly", "Local / regional government", "Public employment service", "Social insurance", "Other social actors (e.g. NGOs)", "Public support service providers"], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.777777777777777 ...
# <div>                            <div id="6939a446-19ca-4133-9b60-6d35b7fd02fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6939a446-19ca-4133-9b60-6d35b7fd02fc")) {                    Plotly.newPlot(                        "6939a446-19ca-4133-9b60-6d35b7fd02fc",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "actors=%{label}<br>Relative freq=%{value}<extra></extra>", "labels": ["National government", "Company / Companies", "Trade unions", "Employers' organisations", "Social partners jointly", "Local / regional government", "Public employment service", "Social insurance", "Other social actors (e.g. NGOs)", "Public support service providers"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [38.36, 18.97, 7.9, 7.29, 6.45, 4.91, 4.53, 3.83, 3.36, 2.57]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d":  ...
#                                  target_groups  Relative freq
# 0             Employees in standard employment          15.97
# 1             Sector specific set of companies          14.02
# 2                       Particular professions           6.67
# 3                                Self-employed           6.60
# 4                                         SMEs           6.13
# 5                                   Unemployed           4.78
# 6               One person or microenterprises           4.38
# 7                      Other groups of workers           3.17
# 8                           Solo-self-employed           3.03
# 9  Workers in non-standard forms of employment           2.83
# <div>                            <div id="bdbf14cb-7470-4583-b8c9-6d2f176abaf8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bdbf14cb-7470-4583-b8c9-6d2f176abaf8")) {                    Plotly.newPlot(                        "bdbf14cb-7470-4583-b8c9-6d2f176abaf8",                        [{"alignmentgroup": "True", "hovertemplate": "Relative freq=%{x}<br>target_groups=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "h", "showlegend": false, "textposition": "auto", "type": "bar", "x": [15.97, 14.02, 6.67, 6.6, 6.13, 4.78, 4.38, 3.17, 3.03, 2.83], "xaxis": "x", "y": ["Employees in standard employment", "Sector specific set of companies", "Particular professions", "Self-employed", "SMEs", "Unemployed", "One person or microenterprises", "Other groups of workers", "Solo-self-employed", "Workers in non-standard forms of employment"], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.777777777 ...
# <div>                            <div id="67f4741f-05b5-4bec-80a6-a5c41f3511d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67f4741f-05b5-4bec-80a6-a5c41f3511d3")) {                    Plotly.newPlot(                        "67f4741f-05b5-4bec-80a6-a5c41f3511d3",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "target_groups=%{label}<br>Relative freq=%{value}<extra></extra>", "labels": ["Employees in standard employment", "Sector specific set of companies", "Particular professions", "Self-employed", "SMEs", "Unemployed", "One person or microenterprises", "Other groups of workers", "Solo-self-employed", "Workers in non-standard forms of employment"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [15.97, 14.02, 6.67, 6.6, 6.13, 4.78, 4.38, 3.17, 3.03, 2.83]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mes ...
#          Businesses  Relative freq
# 0  Businesses_False          65.67
# 1   Businesses_True          34.33
# ...
# <div>                            <div id="669a3868-eeac-416f-a0f2-52b8e0fdbff1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("669a3868-eeac-416f-a0f2-52b8e0fdbff1")) {                    Plotly.newPlot(                        "669a3868-eeac-416f-a0f2-52b8e0fdbff1",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "Workers=%{label}<br>Relative freq=%{value}<extra></extra>", "labels": ["Workers_False", "Workers_True"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [52.35, 47.65]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "t ...
#                        funding  Relative freq
# 0               National funds          46.41
# 1  No special funding required          19.45
# 2                    Companies          10.48
# 3               European Funds           8.69
# 4                     Employer           4.48
# 5               Regional funds           2.90
# 6                        Other           1.79
# 7       Employers organisation           1.72
# 8                  Local funds           1.66
# 9                    Employees           1.24
# <div>                            <div id="82e868c3-fa57-41a8-ad08-f1c05bdb2327" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82e868c3-fa57-41a8-ad08-f1c05bdb2327")) {                    Plotly.newPlot(                        "82e868c3-fa57-41a8-ad08-f1c05bdb2327",                        [{"alignmentgroup": "True", "hovertemplate": "Relative freq=%{x}<br>funding=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "h", "showlegend": false, "textposition": "auto", "type": "bar", "x": [46.41, 19.45, 10.48, 8.69, 4.48, 2.9, 1.79, 1.72, 1.66, 1.24], "xaxis": "x", "y": ["National funds", "No special funding required", "Companies", "European Funds", "Employer", "Regional funds", "Other", "Employers organisation", "Local funds", "Employees"], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontou ...
# <div>                            <div id="c2658734-a609-44a6-b911-99cbb36f7f4f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2658734-a609-44a6-b911-99cbb36f7f4f")) {                    Plotly.newPlot(                        "c2658734-a609-44a6-b911-99cbb36f7f4f",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "funding=%{label}<br>Relative freq=%{value}<extra></extra>", "labels": ["National funds", "No special funding required", "Companies", "European Funds", "Employer", "Regional funds", "Other", "Employers organisation", "Local funds", "Employees"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [46.41, 19.45, 10.48, 8.69, 4.48, 2.9, 1.79, 1.72, 1.66, 1.24]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {" ...

# %% [markdown]
# ## Analysis and visualization:
# - Z score.
# - cumulative frequencies
# - difference in neighboring frequencies

# %%
for key in eda_result.keys():
    data = eda_result[key].copy()
    column_name = data.columns[1]
    zscore_column = data.columns[0]+'_z_score'
    cumulative_freq = 'Cumulative freq'
    diff_freq = 'Diff freq'
    data[zscore_column] = round((data[column_name]-data[column_name].mean())/data[column_name].std(),2)
    data[cumulative_freq] = data[column_name].cumsum()
    data[diff_freq] = data[column_name].diff()
    display(Markdown(f"Std deviation for [{key}] is [{round(data[column_name].std(),2)}]"))
    display(data)
    px.bar(data,x=data.columns[2],y=data.columns[0]).show()
    px.bar(data,x=data.columns[0],y=data.columns[3]).show()
    px.bar(data,x=data.columns[0],y=data.columns[4]).show()
# Out:
# Std deviation for [country] is [1.12]
#            country  Relative freq  country_z_score  Cumulative freq  Diff freq
# 0            Spain           6.66             2.96             6.66        NaN
# 1            Italy           5.12             1.59            11.78      -1.54
# 2           Greece           5.04             1.52            16.82      -0.08
# 3          Germany           4.95             1.44            21.77      -0.09
# 4          Austria           4.87             1.37            26.64      -0.08
# 5         Portugal           4.53             1.06            31.17      -0.34
# 6           France           4.01             0.60            35.18      -0.52
# 7          Croatia           3.67             0.30            38.85      -0.34
# 8        Lithuania           3.50             0.15            42.35      -0.17
# 9           Norway           3.50             0.15            45.85       0.00
# 10         Czechia           3.42             0.08            49.27      -0.08
# 11         Belgium           3.33            -0.00            52.60      -0.09
# 12         Finland           3.16            -0.15            55.76      -0.17
# 13     Netherlands           3.16            -0.15            58.92       0.00
# 14           Malta           3.07            -0.23            61.99      -0.09
# 15      Luxembourg           3.07            -0.23            65.06       0.00
# 16          Poland           3.07            -0.23            68.13       0.00
# 17          Cyprus           2.90            -0.38            71.03      -0.17
# 18        Slovenia           2.90            -0.38            73.93       0.00
# 19        Slovakia           2.82            -0.46            76.75      -0.08
# 20          Latvia           2.82            -0.46            79.57       0.00
# 21         Denmark           2.82            -0.46            82.39       0.00
# 22         Romania           2.65            -0.61            85.04      -0.17
# 23  United Kingdom           2.56            -0.69            87.60      -0.09
# 24          Sweden           2.39            -0.84            89.99      -0.17
# 25        Bulgaria           2.22            -0.99            92.21      -0.17
# 26         Hungary           2.13            -1.07            94.34      -0.09
# 27         Ireland           2.05            -1.14            96.39      -0.08
# 28  European Union           1.88            -1.29            98.27      -0.17
# 29         Estonia           1.71            -1.44            99.98      -0.17
# <div>                            <div id="a0c63f64-0f43-425c-bfef-b6fb0e068af6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a0c63f64-0f43-425c-bfef-b6fb0e068af6")) {                    Plotly.newPlot(                        "a0c63f64-0f43-425c-bfef-b6fb0e068af6",                        [{"alignmentgroup": "True", "hovertemplate": "country_z_score=%{x}<br>country=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "h", "showlegend": false, "textposition": "auto", "type": "bar", "x": [2.96, 1.59, 1.52, 1.44, 1.37, 1.06, 0.6, 0.3, 0.15, 0.15, 0.08, -0.0, -0.15, -0.15, -0.23, -0.23, -0.23, -0.38, -0.38, -0.46, -0.46, -0.46, -0.61, -0.69, -0.84, -0.99, -1.07, -1.14, -1.29, -1.44], "xaxis": "x", "y": ["Spain", "Italy", "Greece", "Germany", "Austria", "Portugal", "France", "Croatia", "Lithuania", "Norway", "Czechia", "Belgium", "Finland", "Netherlands", "Malta", "Luxembourg", "Poland", "Cyprus", "Slovenia", "Slovakia", "Latvia", "Denmark", "Romania", "United Kingdom", "Sweden", "Bulgaria", "Hungary", "Ireland", "European Union", "Estonia"], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale":  ...
# <div>                            <div id="12ae7c26-c561-41f3-9a9f-1cf04c82fe12" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12ae7c26-c561-41f3-9a9f-1cf04c82fe12")) {                    Plotly.newPlot(                        "12ae7c26-c561-41f3-9a9f-1cf04c82fe12",                        [{"alignmentgroup": "True", "hovertemplate": "country=%{x}<br>Cumulative freq=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Spain", "Italy", "Greece", "Germany", "Austria", "Portugal", "France", "Croatia", "Lithuania", "Norway", "Czechia", "Belgium", "Finland", "Netherlands", "Malta", "Luxembourg", "Poland", "Cyprus", "Slovenia", "Slovakia", "Latvia", "Denmark", "Romania", "United Kingdom", "Sweden", "Bulgaria", "Hungary", "Ireland", "European Union", "Estonia"], "xaxis": "x", "y": [6.66, 11.780000000000001, 16.82, 21.77, 26.64, 31.17, 35.18, 38.85, 42.35, 45.85, 49.27, 52.6, 55.760000000000005, 58.92, 61.99, 65.06, 68.13, 71.03, 73.93, 76.75, 79.57, 82.38999999999999, 85.03999999999999, 87.6, 89.99, 92.21, 94.33999999999999, 96.38999999999999, 98.26999999999998, 99.97999999999998], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]],  ...
# <div>                            <div id="ee73e7ee-a185-4921-9720-cd5857040e2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee73e7ee-a185-4921-9720-cd5857040e2e")) {                    Plotly.newPlot(                        "ee73e7ee-a185-4921-9720-cd5857040e2e",                        [{"alignmentgroup": "True", "hovertemplate": "country=%{x}<br>Diff freq=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Spain", "Italy", "Greece", "Germany", "Austria", "Portugal", "France", "Croatia", "Lithuania", "Norway", "Czechia", "Belgium", "Finland", "Netherlands", "Malta", "Luxembourg", "Poland", "Cyprus", "Slovenia", "Slovakia", "Latvia", "Denmark", "Romania", "United Kingdom", "Sweden", "Bulgaria", "Hungary", "Ireland", "European Union", "Estonia"], "xaxis": "x", "y": [null, -1.54, -0.08000000000000007, -0.08999999999999986, -0.08000000000000007, -0.33999999999999986, -0.5200000000000005, -0.33999999999999986, -0.16999999999999993, 0.0, -0.08000000000000007, -0.08999999999999986, -0.16999999999999993, 0.0, -0.0900000000000003, 0.0, 0.0, -0.16999999999999993, 0.0, -0.08000000000000007, 0.0, 0.0, -0.16999999999999993, -0.08999999999999986, -0.16999999999999993, -0.16999999999999993, -0.0900000000000003, -0.08000000000000007, -0.16999999999999993, -0.16999999999999993], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333,  ...
# Std deviation for [category] is [7.18]
#                                             category  Relative freq  \
# 0               Supporting businesses to stay afloat          28.10
# 1     Protection of workers, adaptation of workplace          14.35
# 2           Income protection beyond short-time work          12.21
# 3  Promoting the economic, labour market and soci...          10.16
# 4  Ensuring business continuity and support for e...           9.65
# 5                Employment protection and retention           9.39
# 6                Measures to prevent social hardship           7.09
# 7               Reorientation of business activities           5.72
# 8        Supporting businesses to get back to normal           3.33
#
#    category_z_score  Cumulative freq  Diff freq
# 0              2.37            28.10        NaN
# 1              0.45            42.45     -13.75
# 2              0.15            54.66      -2.14
# 3             -0.13            64.82      -2.05
# 4             -0.20            74.47      -0.51
# 5             -0.24            83.86      -0.26
# 6             -0.56            90.95      -2.30
# 7             -0.75            96.67      -1.37
# 8             -1.08           100.00      -2.39
# <div>                            <div id="82aaba86-91af-435d-bd50-de8d74fcd44c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82aaba86-91af-435d-bd50-de8d74fcd44c")) {                    Plotly.newPlot(                        "82aaba86-91af-435d-bd50-de8d74fcd44c",                        [{"alignmentgroup": "True", "hovertemplate": "category_z_score=%{x}<br>category=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "h", "showlegend": false, "textposition": "auto", "type": "bar", "x": [2.37, 0.45, 0.15, -0.13, -0.2, -0.24, -0.56, -0.75, -1.08], "xaxis": "x", "y": ["Supporting businesses to stay afloat", "Protection of workers, adaptation of workplace", "Income protection beyond short-time work", "Promoting the economic, labour market and social recovery", "Ensuring business continuity and support for essential services", "Employment protection and retention", "Measures to prevent social hardship", "Reorientation of business activities", "Supporting businesses to get back to normal"], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"],  ...
# <div>                            <div id="d060f683-ee05-4012-80b3-dbed3e3cf0dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d060f683-ee05-4012-80b3-dbed3e3cf0dc")) {                    Plotly.newPlot(                        "d060f683-ee05-4012-80b3-dbed3e3cf0dc",                        [{"alignmentgroup": "True", "hovertemplate": "category=%{x}<br>Cumulative freq=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Supporting businesses to stay afloat", "Protection of workers, adaptation of workplace", "Income protection beyond short-time work", "Promoting the economic, labour market and social recovery", "Ensuring business continuity and support for essential services", "Employment protection and retention", "Measures to prevent social hardship", "Reorientation of business activities", "Supporting businesses to get back to normal"], "xaxis": "x", "y": [28.1, 42.45, 54.660000000000004, 64.82000000000001, 74.47000000000001, 83.86000000000001, 90.95000000000002, 96.67000000000002, 100.00000000000001], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewid ...
# <div>                            <div id="510e0808-c393-4d22-92fc-5a463463fe6e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("510e0808-c393-4d22-92fc-5a463463fe6e")) {                    Plotly.newPlot(                        "510e0808-c393-4d22-92fc-5a463463fe6e",                        [{"alignmentgroup": "True", "hovertemplate": "category=%{x}<br>Diff freq=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Supporting businesses to stay afloat", "Protection of workers, adaptation of workplace", "Income protection beyond short-time work", "Promoting the economic, labour market and social recovery", "Ensuring business continuity and support for essential services", "Employment protection and retention", "Measures to prevent social hardship", "Reorientation of business activities", "Supporting businesses to get back to normal"], "xaxis": "x", "y": [null, -13.750000000000002, -2.139999999999999, -2.0500000000000007, -0.5099999999999998, -0.2599999999999998, -2.3000000000000007, -1.37, -2.3899999999999997], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outli ...
# Std deviation for [subcategory] is [2.66]
#                                           subcategory  Relative freq  \
# 0                  Direct subsidies (full or partial)          12.89
# 1                                   Access to finance           7.60
# 2   Income support for people in employment (e.g. ...           7.26
# 3                                               Other           5.81
# 4                 Deferral of payments or liabilities           5.55
# 5                      Occupational health and safety           4.95
# 6   Extensions of  income support to workers not c...           4.78
# 7                     Change of production/innovation           4.61
# 8   Active labour market policies, incl. subsidise...           4.61
# 9            Teleworking arrangements, remote working           4.36
# 10  Change of work arrangements (working time, rot...           2.99
# 11  Support for parents and carers (financial or i...           2.82
# 12  Remuneration and rewards for workers in essent...           2.82
# 13  Protection of vulnerable groups (beyond employ...           2.73
# 14            Support for spending, stimulus packages           2.56
# 15                                    Paid sick leave           2.48
# 16                              Well-being of workers           2.13
# 17                                Keeping a safe home           2.05
# 18                      Income support for unemployed           1.96
# 19                 Mobilisation of a larger workforce           1.79
# 20     Smoothing frictions or reallocation of workers           1.62
# 21               Enhancing employability and training           1.54
# 22                       Flexibilisation and security           1.28
# 23     Measures to support a gradual relaunch of work           1.28
# 24      Changes of working hours or work arrangements           1.20
# 25                       Preventing over-indebtedness           0.94
# 26          Working time and working time flexibility           0.94
# 27                                  Wage flexibility            0.85
# 28                       Changes in work organisation           0.85
# 29  Provision of services in kind (e.g. food vouch...           0.68
# 30  Rescue procedures in case of insolvency or ada...           0.43
# 31                               Access to healthcare           0.43
# 32  Creation of platforms for businesses aimed at ...           0.34
# 33               Transfer or redeployment of workers            0.34
# 34                              Matching / networking           0.34
# 35                     Changes of management approach           0.17
#
#     subcategory_z_score  Cumulative freq  Diff freq
# 0                  3.80            12.89        NaN
# 1                  1.81            20.49      -5.29
# 2                  1.69            27.75      -0.34
# 3                  1.14            33.56      -1.45
# 4                  1.04            39.11      -0.26
# 5                  0.82            44.06      -0.60
# 6                  0.75            48.84      -0.17
# 7                  0.69            53.45      -0.17
# 8                  0.69            58.06       0.00
# 9                  0.60            62.42      -0.25
# 10                 0.08            65.41      -1.37
# 11                 0.02            68.23      -0.17
# 12                 0.02            71.05       0.00
# 13                -0.02            73.78      -0.09
# 14                -0.08            76.34      -0.17
# 15                -0.11            78.82      -0.08
# 16                -0.24            80.95      -0.35
# 17                -0.27            83.00      -0.08
# 18                -0.31            84.96      -0.09
# 19                -0.37            86.75      -0.17
# 20                -0.44            88.37      -0.17
# 21                -0.47            89.91      -0.08
# 22                -0.56            91.19      -0.26
# 23                -0.56            92.47       0.00
# 24                -0.59            93.67      -0.08
# 25                -0.69            94.61      -0.26
# 26                -0.69            95.55       0.00
# 27                -0.73            96.40      -0.09
# 28                -0.73            97.25       0.00
# 29                -0.79            97.93      -0.17
# 30                -0.88            98.36      -0.25
# 31                -0.88            98.79       0.00
# 32                -0.92            99.13      -0.09
# 33                -0.92            99.47       0.00
# 34                -0.92            99.81       0.00
# 35                -0.98            99.98      -0.17
# <div>                            <div id="e88c6666-e297-44e2-b5aa-64206498e92b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e88c6666-e297-44e2-b5aa-64206498e92b")) {                    Plotly.newPlot(                        "e88c6666-e297-44e2-b5aa-64206498e92b",                        [{"alignmentgroup": "True", "hovertemplate": "subcategory_z_score=%{x}<br>subcategory=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "h", "showlegend": false, "textposition": "auto", "type": "bar", "x": [3.8, 1.81, 1.69, 1.14, 1.04, 0.82, 0.75, 0.69, 0.69, 0.6, 0.08, 0.02, 0.02, -0.02, -0.08, -0.11, -0.24, -0.27, -0.31, -0.37, -0.44, -0.47, -0.56, -0.56, -0.59, -0.69, -0.69, -0.73, -0.73, -0.79, -0.88, -0.88, -0.92, -0.92, -0.92, -0.98], "xaxis": "x", "y": ["Direct subsidies (full or partial)", "Access to finance", "Income support for people in employment (e.g. short-time work)", "Other", "Deferral of payments or liabilities", "Occupational health and safety", "Extensions of  income support to workers not covered by any kind of protection scheme", "Change of production/innovation", "Active labour market policies, incl. subsidised job creation", "Teleworking arrangements, remote working", "Change of work arrangements (working time, rota schemes)", "Support for parents and carers (financial or in kind)", "Remuneration and rewards for workers in essential services", "Protection of vulnerable groups (beyond employment support)", "Support for spending, stimulus packages", "Paid sick leave", "Well-being of workers", "Keeping a safe home", "Income support for unemployed", "Mobilisation of a larger workforce", "Smoothing frictions or reallocation of workers", "Enhancing employability and training", "Flexibilisation and security", "Measures to support a gradual relaunch of work", "Changes of working hours or work arrangements", "Preventing over-indebtedness", "Working time and working time flexibility", "Wage flexibility ", "Changes in work organisation", "Provision of services in kind (e.g. food vouchers)", "Rescue procedures in case of insolvency or adaptation of insolvency regulation", "Access to healthcare", "Creation of platforms for businesses aimed at customer", "Transfer or redeployment of workers ", "Matching / networking", "Changes of management approach"], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, ...
# <div>                            <div id="b08acf66-4b0f-41cd-823d-7fb00ceaea4b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b08acf66-4b0f-41cd-823d-7fb00ceaea4b")) {                    Plotly.newPlot(                        "b08acf66-4b0f-41cd-823d-7fb00ceaea4b",                        [{"alignmentgroup": "True", "hovertemplate": "subcategory=%{x}<br>Cumulative freq=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Direct subsidies (full or partial)", "Access to finance", "Income support for people in employment (e.g. short-time work)", "Other", "Deferral of payments or liabilities", "Occupational health and safety", "Extensions of  income support to workers not covered by any kind of protection scheme", "Change of production/innovation", "Active labour market policies, incl. subsidised job creation", "Teleworking arrangements, remote working", "Change of work arrangements (working time, rota schemes)", "Support for parents and carers (financial or in kind)", "Remuneration and rewards for workers in essential services", "Protection of vulnerable groups (beyond employment support)", "Support for spending, stimulus packages", "Paid sick leave", "Well-being of workers", "Keeping a safe home", "Income support for unemployed", "Mobilisation of a larger workforce", "Smoothing frictions or reallocation of workers", "Enhancing employability and training", "Flexibilisation and security", "Measures to support a gradual relaunch of work", "Changes of working hours or work arrangements", "Preventing over-indebtedness", "Working time and working time flexibility", "Wage flexibility ", "Changes in work organisation", "Provision of services in kind (e.g. food vouchers)", "Rescue procedures in case of insolvency or adaptation of insolvency regulation", "Access to healthcare", "Creation of platforms for businesses aimed at customer", "Transfer or redeployment of workers ", "Matching / networking", "Changes of management approach"], "xaxis": "x", "y": [12.89, 20.490000000000002, 27.75, 33.56, 39.11, 44.06, 48.84, 53.45, 58.06, 62.42, 65.41, 68.22999999999999, 71.04999999999998, 73.77999999999999, 76.33999999999999, 78.82, 80.94999999999999, 82.99999999999999, 84.95999999999998, 86.74999999999999, 88.36999999999999, 89.91, 91.19, 92.47, 93.67, 94.61, 95.55, 96.39999999999999, 97.24999999999999, 97.92999999999999, 98.36, 98.79, 99.13000000000001, 99.47000000000001, 99.81000000000002, 99.98000000000002], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"c ...
# <div>                            <div id="e8484884-8b28-43a1-a241-30fefa091f25" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8484884-8b28-43a1-a241-30fefa091f25")) {                    Plotly.newPlot(                        "e8484884-8b28-43a1-a241-30fefa091f25",                        [{"alignmentgroup": "True", "hovertemplate": "subcategory=%{x}<br>Diff freq=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Direct subsidies (full or partial)", "Access to finance", "Income support for people in employment (e.g. short-time work)", "Other", "Deferral of payments or liabilities", "Occupational health and safety", "Extensions of  income support to workers not covered by any kind of protection scheme", "Change of production/innovation", "Active labour market policies, incl. subsidised job creation", "Teleworking arrangements, remote working", "Change of work arrangements (working time, rota schemes)", "Support for parents and carers (financial or in kind)", "Remuneration and rewards for workers in essential services", "Protection of vulnerable groups (beyond employment support)", "Support for spending, stimulus packages", "Paid sick leave", "Well-being of workers", "Keeping a safe home", "Income support for unemployed", "Mobilisation of a larger workforce", "Smoothing frictions or reallocation of workers", "Enhancing employability and training", "Flexibilisation and security", "Measures to support a gradual relaunch of work", "Changes of working hours or work arrangements", "Preventing over-indebtedness", "Working time and working time flexibility", "Wage flexibility ", "Changes in work organisation", "Provision of services in kind (e.g. food vouchers)", "Rescue procedures in case of insolvency or adaptation of insolvency regulation", "Access to healthcare", "Creation of platforms for businesses aimed at customer", "Transfer or redeployment of workers ", "Matching / networking", "Changes of management approach"], "xaxis": "x", "y": [null, -5.290000000000001, -0.33999999999999986, -1.4500000000000002, -0.2599999999999998, -0.5999999999999996, -0.16999999999999993, -0.16999999999999993, 0.0, -0.25, -1.37, -0.17000000000000037, 0.0, -0.08999999999999986, -0.16999999999999993, -0.08000000000000007, -0.3500000000000001, -0.08000000000000007, -0.08999999999999986, -0.16999999999999993, -0.16999999999999993, -0.08000000000000007, -0.26, 0.0, -0.08000000000000007, -0.26, 0.0, -0.08999999999999997, 0.0, -0.16999999999999993, -0.25000000000000006, 0.0, -0.08999999999999997, 0.0, 0.0, -0.17], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"] ...
# Std deviation for [actors] is [10.59]
#                               actors  Relative freq  actors_z_score  \
# 0                National government          38.36            2.83
# 1                Company / Companies          18.97            1.00
# 2                       Trade unions           7.90           -0.04
# 3           Employers' organisations           7.29           -0.10
# 4            Social partners jointly           6.45           -0.18
# 5        Local / regional government           4.91           -0.32
# 6          Public employment service           4.53           -0.36
# 7                   Social insurance           3.83           -0.42
# 8    Other social actors (e.g. NGOs)           3.36           -0.47
# 9   Public support service providers           2.57           -0.54
# 10              EU (Council, EC, EP)           1.40           -0.65
# 11          EU level social partners           0.42           -0.75
#
#     Cumulative freq  Diff freq
# 0             38.36        NaN
# 1             57.33     -19.39
# 2             65.23     -11.07
# 3             72.52      -0.61
# 4             78.97      -0.84
# 5             83.88      -1.54
# 6             88.41      -0.38
# 7             92.24      -0.70
# 8             95.60      -0.47
# 9             98.17      -0.79
# 10            99.57      -1.17
# 11            99.99      -0.98
# ...
# Std deviation for [funding] is [13.23]
#                         funding  Relative freq  funding_z_score  \
# 0                National funds          46.41             2.88
# 1   No special funding required          19.45             0.84
# 2                     Companies          10.48             0.16
# 3                European Funds           8.69             0.03
# 4                      Employer           4.48            -0.29
# 5                Regional funds           2.90            -0.41
# 6                         Other           1.79            -0.49
# 7        Employers organisation           1.72            -0.50
# 8                   Local funds           1.66            -0.50
# 9                     Employees           1.24            -0.54
# 10                  Trade union           0.97            -0.56
# 11      Social partners jointly           0.21            -0.61
#
#     Cumulative freq  Diff freq
# 0             46.41        NaN
# 1             65.86     -26.96
# 2             76.34      -8.97
# 3             85.03      -1.79
# 4             89.51      -4.21
# 5             92.41      -1.58
# 6             94.20      -1.11
# 7             95.92      -0.07
# 8             97.58      -0.06
# 9             98.82      -0.42
# 10            99.79      -0.27
# 11           100.00      -0.76
# <div>                            <div id="ca89d5ac-d975-4d21-99cb-5d85ae106f81" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca89d5ac-d975-4d21-99cb-5d85ae106f81")) {                    Plotly.newPlot(                        "ca89d5ac-d975-4d21-99cb-5d85ae106f81",                        [{"alignmentgroup": "True", "hovertemplate": "funding_z_score=%{x}<br>funding=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "h", "showlegend": false, "textposition": "auto", "type": "bar", "x": [2.88, 0.84, 0.16, 0.03, -0.29, -0.41, -0.49, -0.5, -0.5, -0.54, -0.56, -0.61], "xaxis": "x", "y": ["National funds", "No special funding required", "Companies", "European Funds", "Employer", "Regional funds", "Other", "Employers organisation", "Local funds", "Employees", "Trade union", "Social partners jointly"], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a" ...
# <div>                            <div id="33e959d1-c5b9-4ace-99f3-54619227fe38" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33e959d1-c5b9-4ace-99f3-54619227fe38")) {                    Plotly.newPlot(                        "33e959d1-c5b9-4ace-99f3-54619227fe38",                        [{"alignmentgroup": "True", "hovertemplate": "funding=%{x}<br>Cumulative freq=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["National funds", "No special funding required", "Companies", "European Funds", "Employer", "Regional funds", "Other", "Employers organisation", "Local funds", "Employees", "Trade union", "Social partners jointly"], "xaxis": "x", "y": [46.41, 65.86, 76.34, 85.03, 89.51, 92.41000000000001, 94.20000000000002, 95.92000000000002, 97.58000000000001, 98.82000000000001, 99.79, 100.0], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b" ...
# <div>                            <div id="73d2b9fd-4ea5-49d9-978e-d611e0c2366c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73d2b9fd-4ea5-49d9-978e-d611e0c2366c")) {                    Plotly.newPlot(                        "73d2b9fd-4ea5-49d9-978e-d611e0c2366c",                        [{"alignmentgroup": "True", "hovertemplate": "funding=%{x}<br>Diff freq=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["National funds", "No special funding required", "Companies", "European Funds", "Employer", "Regional funds", "Other", "Employers organisation", "Local funds", "Employees", "Trade union", "Social partners jointly"], "xaxis": "x", "y": [null, -26.959999999999997, -8.969999999999999, -1.790000000000001, -4.209999999999999, -1.5800000000000005, -1.1099999999999999, -0.07000000000000006, -0.06000000000000005, -0.41999999999999993, -0.27, -0.76], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4 ...

# %% [markdown]
# ## Additional functions for confidence interval analysis:

# %%
def confidence_interval_with_mean( series : pd.Series):
    se = tmp_s.std()/np.sqrt(series.size)
    mean = tmp_s.mean()
    z = 1.96
    max = __builtins__.max
    min = __builtins__.min
    left_limit = max(round(100*(mean - z*se),2),0)
    right_limit = min(round(100*(mean + z*se),2),100)
    return [left_limit,right_limit]

# %%
def confidence_interval_for_proportion( series : pd.Series):
    conf_int = [ list(sm.stats.proportion_confint(n*p, n)) for p in tmp_s]
    conf_int = pd.DataFrame(conf_int).apply(lambda x: round(100*x,2))
    conf_int = [pd.Interval(row[0],row[1],closed='both') for index,row in conf_int.iterrows()]
    return conf_int

# %%
def z_score_for_series(series : pd.Series):
    return pd.Series(stats.zscore(tmp_s)).apply(lambda x: round(x,2))

# %% [markdown]
# ## Analysis of confidence intervals:
# - calculating the confidence interval for each column
# - calculating the confidence interval for each proportion from column
# - calculating the records from column, that are overrepresented
# - calculating the records from column, that are underrepresented

# %%
for key in eda_result.keys():
    data = eda_result[key].copy()
    n = data.size
    tmp_s = data[data.columns[1]].copy()
    tmp_s/=100
    ci_mean = confidence_interval_with_mean(tmp_s)
    display(Markdown(f"Confidence Interval for {key} is : [{ci_mean[0]}%, {ci_mean[1]}%]"))
    data["Confidence Interval"]= confidence_interval_for_proportion(tmp_s)
    data["z_score"] = z_score_for_series(tmp_s)
    display(data)
    display(Markdown(f"Overrepresented records from column : {key}"))
    rel_f = 'Relative freq'
    display(data.loc[data[rel_f]>ci_mean[1]])
    display(Markdown(f"Normal represented records from column : {key}"))
    display(data.loc[(data[rel_f]>=ci_mean[0])&(data[rel_f]<=ci_mean[1])])
    display(Markdown(f"Underrepresented records from column : {key}"))
    display(data.loc[data[rel_f]<ci_mean[0]])
# Out:
# Confidence Interval for country is : [2.93%, 3.74%]
#            country  Relative freq Confidence Interval  z_score
# 0            Spain           6.66       [0.35, 12.97]     3.01
# 1            Italy           5.12         [0.0, 10.7]     1.62
# 2           Greece           5.04        [0.0, 10.58]     1.54
# 3          Germany           4.95        [0.0, 10.44]     1.46
# 4          Austria           4.87        [0.0, 10.32]     1.39
# 5         Portugal           4.53         [0.0, 9.79]     1.08
# 6           France           4.01         [0.0, 8.97]     0.61
# 7          Croatia           3.67         [0.0, 8.43]     0.31
# 8        Lithuania           3.50         [0.0, 8.15]     0.15
# 9           Norway           3.50         [0.0, 8.15]     0.15
# 10         Czechia           3.42         [0.0, 8.02]     0.08
# 11         Belgium           3.33         [0.0, 7.87]    -0.00
# 12         Finland           3.16         [0.0, 7.59]    -0.16
# 13     Netherlands           3.16         [0.0, 7.59]    -0.16
# 14           Malta           3.07         [0.0, 7.43]    -0.24
# 15      Luxembourg           3.07         [0.0, 7.43]    -0.24
# 16          Poland           3.07         [0.0, 7.43]    -0.24
# 17          Cyprus           2.90         [0.0, 7.15]    -0.39
# 18        Slovenia           2.90         [0.0, 7.15]    -0.39
# 19        Slovakia           2.82         [0.0, 7.01]    -0.46
# 20          Latvia           2.82         [0.0, 7.01]    -0.46
# 21         Denmark           2.82         [0.0, 7.01]    -0.46
# 22         Romania           2.65         [0.0, 6.71]    -0.62
# 23  United Kingdom           2.56         [0.0, 6.56]    -0.70
# 24          Sweden           2.39         [0.0, 6.25]    -0.85
# 25        Bulgaria           2.22         [0.0, 5.95]    -1.01
# 26         Hungary           2.13         [0.0, 5.78]    -1.09
# 27         Ireland           2.05         [0.0, 5.64]    -1.16
# 28  European Union           1.88         [0.0, 5.32]    -1.31
# 29         Estonia           1.71         [0.0, 4.99]    -1.47
# Overrepresented records from column : country
#     country  Relative freq Confidence Interval  z_score
# 0     Spain           6.66       [0.35, 12.97]     3.01
# 1     Italy           5.12         [0.0, 10.7]     1.62
# 2    Greece           5.04        [0.0, 10.58]     1.54
# 3   Germany           4.95        [0.0, 10.44]     1.46
# 4   Austria           4.87        [0.0, 10.32]     1.39
# 5  Portugal           4.53         [0.0, 9.79]     1.08
# 6    France           4.01         [0.0, 8.97]     0.61
# Normal represented records from column : country
#         country  Relative freq Confidence Interval  z_score
# 7       Croatia           3.67         [0.0, 8.43]     0.31
# 8     Lithuania           3.50         [0.0, 8.15]     0.15
# 9        Norway           3.50         [0.0, 8.15]     0.15
# 10      Czechia           3.42         [0.0, 8.02]     0.08
# 11      Belgium           3.33         [0.0, 7.87]    -0.00
# 12      Finland           3.16         [0.0, 7.59]    -0.16
# 13  Netherlands           3.16         [0.0, 7.59]    -0.16
# 14        Malta           3.07         [0.0, 7.43]    -0.24
# 15   Luxembourg           3.07         [0.0, 7.43]    -0.24
# 16       Poland           3.07         [0.0, 7.43]    -0.24
# Underrepresented records from column : country
#            country  Relative freq Confidence Interval  z_score
# 17          Cyprus           2.90         [0.0, 7.15]    -0.39
# 18        Slovenia           2.90         [0.0, 7.15]    -0.39
# 19        Slovakia           2.82         [0.0, 7.01]    -0.46
# 20          Latvia           2.82         [0.0, 7.01]    -0.46
# 21         Denmark           2.82         [0.0, 7.01]    -0.46
# 22         Romania           2.65         [0.0, 6.71]    -0.62
# 23  United Kingdom           2.56         [0.0, 6.56]    -0.70
# 24          Sweden           2.39         [0.0, 6.25]    -0.85
# 25        Bulgaria           2.22         [0.0, 5.95]    -1.01
# 26         Hungary           2.13         [0.0, 5.78]    -1.09
# 27         Ireland           2.05         [0.0, 5.64]    -1.16
# 28  European Union           1.88         [0.0, 5.32]    -1.31
# 29         Estonia           1.71         [0.0, 4.99]    -1.47
# Confidence Interval for category is : [6.42%, 15.8%]
#                                             category  Relative freq  \
# 0               Supporting businesses to stay afloat          28.10
# 1     Protection of workers, adaptation of workplace          14.35
# 2           Income protection beyond short-time work          12.21
# 3  Promoting the economic, labour market and soci...          10.16
# 4  Ensuring business continuity and support for e...           9.65
# 5                Employment protection and retention           9.39
# 6                Measures to prevent social hardship           7.09
# 7               Reorientation of business activities           5.72
# 8        Supporting businesses to get back to normal           3.33
#
#   Confidence Interval  z_score
# 0       [7.34, 48.86]     2.51
# 1        [0.0, 30.55]     0.48
# 2        [0.0, 27.33]     0.16
# 3        [0.0, 24.12]    -0.14
# 4        [0.0, 23.29]    -0.22
# 5        [0.0, 22.87]    -0.25
# 6        [0.0, 18.95]    -0.59
# 7        [0.0, 16.45]    -0.80
# 8        [0.0, 11.62]    -1.15
# Overrepresented records from column : category
#                                category  Relative freq Confidence Interval  \
# 0  Supporting businesses to stay afloat           28.1       [7.34, 48.86]
#
#    z_score
# 0     2.51
# Normal represented records from column : category
#                                             category  Relative freq  \
# 1     Protection of workers, adaptation of workplace          14.35
# 2           Income protection beyond short-time work          12.21
# 3  Promoting the economic, labour market and soci...          10.16
# 4  Ensuring business continuity and support for e...           9.65
# 5                Employment protection and retention           9.39
# 6                Measures to prevent social hardship           7.09
#
#   Confidence Interval  z_score
# 1        [0.0, 30.55]     0.48
# 2        [0.0, 27.33]     0.16
# 3        [0.0, 24.12]    -0.14
# 4        [0.0, 23.29]    -0.22
# 5        [0.0, 22.87]    -0.25
# 6        [0.0, 18.95]    -0.59
# Underrepresented records from column : category
#                                       category  Relative freq  \
# 7         Reorientation of business activities           5.72
# 8  Supporting businesses to get back to normal           3.33
#
#   Confidence Interval  z_score
# 7        [0.0, 16.45]    -0.80
# 8        [0.0, 11.62]    -1.15
# Confidence Interval for subcategory is : [1.91%, 3.65%]
#                                           subcategory  Relative freq  \
# 0                  Direct subsidies (full or partial)          12.89
# 1                                   Access to finance           7.60
# 2   Income support for people in employment (e.g. ...           7.26
# 3                                               Other           5.81
# 4                 Deferral of payments or liabilities           5.55
# 5                      Occupational health and safety           4.95
# 6   Extensions of  income support to workers not c...           4.78
# 7                     Change of production/innovation           4.61
# 8   Active labour market policies, incl. subsidise...           4.61
# 9            Teleworking arrangements, remote working           4.36
# 10  Change of work arrangements (working time, rot...           2.99
# 11  Support for parents and carers (financial or i...           2.82
# 12  Remuneration and rewards for workers in essent...           2.82
# 13  Protection of vulnerable groups (beyond employ...           2.73
# 14            Support for spending, stimulus packages           2.56
# 15                                    Paid sick leave           2.48
# 16                              Well-being of workers           2.13
# 17                                Keeping a safe home           2.05
# 18                      Income support for unemployed           1.96
# 19                 Mobilisation of a larger workforce           1.79
# 20     Smoothing frictions or reallocation of workers           1.62
# 21               Enhancing employability and training           1.54
# 22                       Flexibilisation and security           1.28
# 23     Measures to support a gradual relaunch of work           1.28
# 24      Changes of working hours or work arrangements           1.20
# 25                       Preventing over-indebtedness           0.94
# 26          Working time and working time flexibility           0.94
# 27                                  Wage flexibility            0.85
# 28                       Changes in work organisation           0.85
# 29  Provision of services in kind (e.g. food vouch...           0.68
# 30  Rescue procedures in case of insolvency or ada...           0.43
# 31                               Access to healthcare           0.43
# 32  Creation of platforms for businesses aimed at ...           0.34
# 33               Transfer or redeployment of workers            0.34
# 34                              Matching / networking           0.34
# 35                     Changes of management approach           0.17
#
#    Confidence Interval  z_score
# 0        [5.15, 20.63]     3.86
# 1        [1.48, 13.72]     1.84
# 2        [1.27, 13.25]     1.71
# 3        [0.41, 11.21]     1.16
# 4        [0.26, 10.84]     1.06
# 5          [0.0, 9.96]     0.83
# 6          [0.0, 9.71]     0.76
# 7          [0.0, 9.45]     0.70
# 8          [0.0, 9.45]     0.70
# 9          [0.0, 9.08]     0.60
# 10         [0.0, 6.92]     0.08
# 11         [0.0, 6.64]     0.02
# 12         [0.0, 6.64]     0.02
# 13         [0.0, 6.49]    -0.02
# 14         [0.0, 6.21]    -0.08
# 15         [0.0, 6.07]    -0.11
# 16         [0.0, 5.47]    -0.25
# 17         [0.0, 5.32]    -0.28
# 18         [0.0, 5.16]    -0.31
# 19         [0.0, 4.85]    -0.38
# 20         [0.0, 4.54]    -0.44
# 21         [0.0, 4.38]    -0.47
# 22         [0.0, 3.88]    -0.57
# 23         [0.0, 3.88]    -0.57
# 24         [0.0, 3.72]    -0.60
# 25         [0.0, 3.17]    -0.70
# 26         [0.0, 3.17]    -0.70
# 27         [0.0, 2.97]    -0.74
# 28         [0.0, 2.97]    -0.74
# 29         [0.0, 2.58]    -0.80
# 30         [0.0, 1.94]    -0.90
# 31         [0.0, 1.94]    -0.90
# 32         [0.0, 1.68]    -0.93
# 33         [0.0, 1.68]    -0.93
# 34         [0.0, 1.68]    -0.93
# 35         [0.0, 1.12]    -0.99
# Overrepresented records from column : subcategory
#                                          subcategory  Relative freq  \
# 0                 Direct subsidies (full or partial)          12.89
# 1                                  Access to finance           7.60
# 2  Income support for people in employment (e.g. ...           7.26
# 3                                              Other           5.81
# 4                Deferral of payments or liabilities           5.55
# 5                     Occupational health and safety           4.95
# 6  Extensions of  income support to workers not c...           4.78
# 7                    Change of production/innovation           4.61
# 8  Active labour market policies, incl. subsidise...           4.61
# 9           Teleworking arrangements, remote working           4.36
#
#   Confidence Interval  z_score
# 0       [5.15, 20.63]     3.86
# 1       [1.48, 13.72]     1.84
# 2       [1.27, 13.25]     1.71
# 3       [0.41, 11.21]     1.16
# 4       [0.26, 10.84]     1.06
# 5         [0.0, 9.96]     0.83
# 6         [0.0, 9.71]     0.76
# 7         [0.0, 9.45]     0.70
# 8         [0.0, 9.45]     0.70
# 9         [0.0, 9.08]     0.60
# Normal represented records from column : subcategory
#                                           subcategory  Relative freq  \
# 10  Change of work arrangements (working time, rot...           2.99
# 11  Support for parents and carers (financial or i...           2.82
# 12  Remuneration and rewards for workers in essent...           2.82
# 13  Protection of vulnerable groups (beyond employ...           2.73
# 14            Support for spending, stimulus packages           2.56
# 15                                    Paid sick leave           2.48
# 16                              Well-being of workers           2.13
# 17                                Keeping a safe home           2.05
# 18                      Income support for unemployed           1.96
#
#    Confidence Interval  z_score
# 10         [0.0, 6.92]     0.08
# 11         [0.0, 6.64]     0.02
# 12         [0.0, 6.64]     0.02
# 13         [0.0, 6.49]    -0.02
# 14         [0.0, 6.21]    -0.08
# 15         [0.0, 6.07]    -0.11
# 16         [0.0, 5.47]    -0.25
# 17         [0.0, 5.32]    -0.28
# 18         [0.0, 5.16]    -0.31
# Underrepresented records from column : subcategory
#                                           subcategory  Relative freq  \
# 19                 Mobilisation of a larger workforce           1.79
# 20     Smoothing frictions or reallocation of workers           1.62
# 21               Enhancing employability and training           1.54
# 22                       Flexibilisation and security           1.28
# 23     Measures to support a gradual relaunch of work           1.28
# 24      Changes of working hours or work arrangements           1.20
# 25                       Preventing over-indebtedness           0.94
# 26          Working time and working time flexibility           0.94
# 27                                  Wage flexibility            0.85
# 28                       Changes in work organisation           0.85
# 29  Provision of services in kind (e.g. food vouch...           0.68
# 30  Rescue procedures in case of insolvency or ada...           0.43
# 31                               Access to healthcare           0.43
# 32  Creation of platforms for businesses aimed at ...           0.34
# 33               Transfer or redeployment of workers            0.34
# 34                              Matching / networking           0.34
# 35                     Changes of management approach           0.17
#
#    Confidence Interval  z_score
# 19         [0.0, 4.85]    -0.38
# 20         [0.0, 4.54]    -0.44
# 21         [0.0, 4.38]    -0.47
# 22         [0.0, 3.88]    -0.57
# 23         [0.0, 3.88]    -0.57
# 24         [0.0, 3.72]    -0.60
# 25         [0.0, 3.17]    -0.70
# 26         [0.0, 3.17]    -0.70
# 27         [0.0, 2.97]    -0.74
# 28         [0.0, 2.97]    -0.74
# 29         [0.0, 2.58]    -0.80
# 30         [0.0, 1.94]    -0.90
# 31         [0.0, 1.94]    -0.90
# 32         [0.0, 1.68]    -0.93
# 33         [0.0, 1.68]    -0.93
# 34         [0.0, 1.68]    -0.93
# 35         [0.0, 1.12]    -0.99
# Confidence Interval for actors is : [2.34%, 14.33%]
#                               actors  Relative freq Confidence Interval  \
# 0                National government          38.36      [18.91, 57.81]
# 1                Company / Companies          18.97       [3.28, 34.66]
# 2                       Trade unions           7.90        [0.0, 18.69]
# 3           Employers' organisations           7.29        [0.0, 17.69]
# 4            Social partners jointly           6.45        [0.0, 16.28]
# 5        Local / regional government           4.91        [0.0, 13.55]
# 6          Public employment service           4.53        [0.0, 12.85]
# 7                   Social insurance           3.83        [0.0, 11.51]
# 8    Other social actors (e.g. NGOs)           3.36        [0.0, 10.57]
# 9   Public support service providers           2.57          [0.0, 8.9]
# 10              EU (Council, EC, EP)           1.40          [0.0, 6.1]
# 11          EU level social partners           0.42         [0.0, 3.01]
#
#     z_score
# 0      2.96
# 1      1.05
# 2     -0.04
# 3     -0.10
# 4     -0.19
# 5     -0.34
# 6     -0.37
# 7     -0.44
# 8     -0.49
# 9     -0.57
# 10    -0.68
# 11    -0.78
# Overrepresented records from column : actors
#                 actors  Relative freq Confidence Interval  z_score
# 0  National government          38.36      [18.91, 57.81]     2.96
# 1  Company / Companies          18.97       [3.28, 34.66]     1.05
# Normal represented records from column : actors
#                              actors  Relative freq Confidence Interval  \
# 2                      Trade unions           7.90        [0.0, 18.69]
# 3          Employers' organisations           7.29        [0.0, 17.69]
# 4           Social partners jointly           6.45        [0.0, 16.28]
# 5       Local / regional government           4.91        [0.0, 13.55]
# 6         Public employment service           4.53        [0.0, 12.85]
# 7                  Social insurance           3.83        [0.0, 11.51]
# 8   Other social actors (e.g. NGOs)           3.36        [0.0, 10.57]
# 9  Public support service providers           2.57          [0.0, 8.9]
#
#    z_score
# 2    -0.04
# 3    -0.10
# 4    -0.19
# 5    -0.34
# 6    -0.37
# 7    -0.44
# 8    -0.49
# 9    -0.57
# Underrepresented records from column : actors
#                       actors  Relative freq Confidence Interval  z_score
# 10      EU (Council, EC, EP)           1.40          [0.0, 6.1]    -0.68
# 11  EU level social partners           0.42         [0.0, 3.01]    -0.78
# Confidence Interval for target_groups is : [1.36%, 3.4%]
#                                   target_groups  Relative freq  \
# 0              Employees in standard employment          15.97
# 1              Sector specific set of companies          14.02
# 2                        Particular professions           6.67
# 3                                 Self-employed           6.60
# 4                                          SMEs           6.13
# 5                                    Unemployed           4.78
# 6                One person or microenterprises           4.38
# 7                       Other groups of workers           3.17
# 8                            Solo-self-employed           3.03
# 9   Workers in non-standard forms of employment           2.83
# 10                             Other businesses           2.83
# 11       Companies providing essential services           2.83
# 12                Workers in essential services           2.76
# 13                          Larger corporations           2.49
# 14                             Disabled workers           1.95
# 15                   Workers in care facilities           1.89
# 16                        Parents in employment           1.82
# 17                                     Disabled           1.82
# 18                     Other groups of citizens           1.68
# 19     The COVID-19 risk group at the workplace           1.48
# 20                                      Parents           1.28
# 21                               Older citizens           1.28
# 22                      The COVID-19 risk group           1.01
# 23                                    Start-ups           1.01
# 24                            Children (minors)           0.94
# 25                             Seasonal workers           0.74
# 26                                Youth (18-25)           0.74
# 27                  Youth (18-25) in employment           0.67
# 28                    People in care facilities           0.47
# 29                       Migrants in employment           0.40
# 30        Older people in employment (aged 55+)           0.34
# 31                               Posted workers           0.27
# 32                               Single parents           0.27
# 33                       Cross-border commuters           0.27
# 34                 Single parents in employment           0.27
# 35                                     Migrants           0.20
# 36                     Contractors of a company           0.20
# 37                                        Women           0.13
# 38                           Undeclared workers           0.13
# 39                             Platform workers           0.07
# 40                                     Refugees           0.07
# 41                               Female workers           0.07
#
#    Confidence Interval  z_score
# 0         [8.14, 23.8]     4.08
# 1         [6.6, 21.44]     3.49
# 2        [1.33, 12.01]     1.29
# 3        [1.29, 11.91]     1.27
# 4         [1.0, 11.26]     1.13
# 5         [0.22, 9.34]     0.72
# 6          [0.0, 8.76]     0.60
# 7          [0.0, 6.92]     0.24
# 8           [0.0, 6.7]     0.20
# 9          [0.0, 6.38]     0.14
# 10         [0.0, 6.38]     0.14
# 11         [0.0, 6.38]     0.14
# 12         [0.0, 6.26]     0.11
# 13         [0.0, 5.82]     0.03
# 14         [0.0, 4.91]    -0.13
# 15          [0.0, 4.8]    -0.15
# 16         [0.0, 4.68]    -0.17
# 17         [0.0, 4.68]    -0.17
# 18         [0.0, 4.43]    -0.21
# 19         [0.0, 4.06]    -0.27
# 20         [0.0, 3.68]    -0.33
# 21         [0.0, 3.68]    -0.33
# 22         [0.0, 3.15]    -0.41
# 23         [0.0, 3.15]    -0.41
# 24          [0.0, 3.0]    -0.43
# 25         [0.0, 2.57]    -0.49
# 26         [0.0, 2.57]    -0.49
# 27         [0.0, 2.41]    -0.51
# 28         [0.0, 1.93]    -0.57
# 29         [0.0, 1.75]    -0.59
# 30         [0.0, 1.58]    -0.61
# 31         [0.0, 1.38]    -0.63
# 32         [0.0, 1.38]    -0.63
# 33         [0.0, 1.38]    -0.63
# 34         [0.0, 1.38]    -0.63
# 35         [0.0, 1.16]    -0.65
# 36         [0.0, 1.16]    -0.65
# 37          [0.0, 0.9]    -0.68
# 38          [0.0, 0.9]    -0.68
# 39         [0.0, 0.64]    -0.69
# 40         [0.0, 0.64]    -0.69
# 41         [0.0, 0.64]    -0.69
# Overrepresented records from column : target_groups
#                       target_groups  Relative freq Confidence Interval  \
# 0  Employees in standard employment          15.97        [8.14, 23.8]
# 1  Sector specific set of companies          14.02        [6.6, 21.44]
# 2            Particular professions           6.67       [1.33, 12.01]
# 3                     Self-employed           6.60       [1.29, 11.91]
# 4                              SMEs           6.13        [1.0, 11.26]
# 5                        Unemployed           4.78        [0.22, 9.34]
# 6    One person or microenterprises           4.38         [0.0, 8.76]
#
#    z_score
# 0     4.08
# 1     3.49
# 2     1.29
# 3     1.27
# 4     1.13
# 5     0.72
# 6     0.60
# Normal represented records from column : target_groups
#                                   target_groups  Relative freq  \
# 7                       Other groups of workers           3.17
# 8                            Solo-self-employed           3.03
# 9   Workers in non-standard forms of employment           2.83
# 10                             Other businesses           2.83
# 11       Companies providing essential services           2.83
# 12                Workers in essential services           2.76
# 13                          Larger corporations           2.49
# 14                             Disabled workers           1.95
# 15                   Workers in care facilities           1.89
# 16                        Parents in employment           1.82
# 17                                     Disabled           1.82
# 18                     Other groups of citizens           1.68
# 19     The COVID-19 risk group at the workplace           1.48
#
#    Confidence Interval  z_score
# 7          [0.0, 6.92]     0.24
# 8           [0.0, 6.7]     0.20
# 9          [0.0, 6.38]     0.14
# 10         [0.0, 6.38]     0.14
# 11         [0.0, 6.38]     0.14
# 12         [0.0, 6.26]     0.11
# 13         [0.0, 5.82]     0.03
# 14         [0.0, 4.91]    -0.13
# 15          [0.0, 4.8]    -0.15
# 16         [0.0, 4.68]    -0.17
# 17         [0.0, 4.68]    -0.17
# 18         [0.0, 4.43]    -0.21
# 19         [0.0, 4.06]    -0.27
# Underrepresented records from column : target_groups
#                             target_groups  Relative freq Confidence Interval  \
# 20                                Parents           1.28         [0.0, 3.68]
# 21                         Older citizens           1.28         [0.0, 3.68]
# 22                The COVID-19 risk group           1.01         [0.0, 3.15]
# 23                              Start-ups           1.01         [0.0, 3.15]
# 24                      Children (minors)           0.94          [0.0, 3.0]
# 25                       Seasonal workers           0.74         [0.0, 2.57]
# 26                          Youth (18-25)           0.74         [0.0, 2.57]
# 27            Youth (18-25) in employment           0.67         [0.0, 2.41]
# 28              People in care facilities           0.47         [0.0, 1.93]
# 29                 Migrants in employment           0.40         [0.0, 1.75]
# 30  Older people in employment (aged 55+)           0.34         [0.0, 1.58]
# 31                         Posted workers           0.27         [0.0, 1.38]
# 32                         Single parents           0.27         [0.0, 1.38]
# 33                 Cross-border commuters           0.27         [0.0, 1.38]
# 34           Single parents in employment           0.27         [0.0, 1.38]
# 35                               Migrants           0.20         [0.0, 1.16]
# 36               Contractors of a company           0.20         [0.0, 1.16]
# 37                                  Women           0.13          [0.0, 0.9]
# 38                     Undeclared workers           0.13          [0.0, 0.9]
# 39                       Platform workers           0.07         [0.0, 0.64]
# 40                               Refugees           0.07         [0.0, 0.64]
# 41                         Female workers           0.07         [0.0, 0.64]
#
#     z_score
# 20    -0.33
# 21    -0.33
# 22    -0.41
# 23    -0.41
# 24    -0.43
# 25    -0.49
# 26    -0.49
# 27    -0.51
# 28    -0.57
# 29    -0.59
# 30    -0.61
# 31    -0.63
# 32    -0.63
# 33    -0.63
# 34    -0.63
# 35    -0.65
# 36    -0.65
# 37    -0.68
# 38    -0.68
# 39    -0.69
# 40    -0.69
# 41    -0.69
# Confidence Interval for Businesses is : [19.29%, 80.71%]
#          Businesses  Relative freq Confidence Interval  z_score
# 0  Businesses_False          65.67      [19.14, 100.0]      1.0
# 1   Businesses_True          34.33        [0.0, 80.86]     -1.0
# Overrepresented records from column : Businesses
# Empty DataFrame
# Columns: [Businesses, Relative freq, Confidence Interval, z_score]
# Index: []
# Normal represented records from column : Businesses
#          Businesses  Relative freq Confidence Interval  z_score
# 0  Businesses_False          65.67      [19.14, 100.0]      1.0
# 1   Businesses_True          34.33        [0.0, 80.86]     -1.0
# Underrepresented records from column : Businesses
# Empty DataFrame
# Columns: [Businesses, Relative freq, Confidence Interval, z_score]
# Index: []
# Confidence Interval for Citizens is : [0%, 100%]
#          Citizens  Relative freq Confidence Interval  z_score
# 0  Citizens_False          92.66       [67.1, 100.0]      1.0
# 1   Citizens_True           7.34         [0.0, 32.9]     -1.0
# Overrepresented records from column : Citizens
# Empty DataFrame
# Columns: [Citizens, Relative freq, Confidence Interval, z_score]
# Index: []
# Normal represented records from column : Citizens
#          Citizens  Relative freq Confidence Interval  z_score
# 0  Citizens_False          92.66       [67.1, 100.0]      1.0
# 1   Citizens_True           7.34         [0.0, 32.9]     -1.0
# Underrepresented records from column : Citizens
# Empty DataFrame
# Columns: [Citizens, Relative freq, Confidence Interval, z_score]
# Index: []
# Confidence Interval for Workers is : [45.39%, 54.61%]
#          Workers  Relative freq Confidence Interval  z_score
# 0  Workers_False          52.35       [3.41, 100.0]      1.0
# 1   Workers_True          47.65        [0.0, 96.59]     -1.0
# Overrepresented records from column : Workers
# Empty DataFrame
# Columns: [Workers, Relative freq, Confidence Interval, z_score]
# Index: []
# Normal represented records from column : Workers
#          Workers  Relative freq Confidence Interval  z_score
# 0  Workers_False          52.35       [3.41, 100.0]      1.0
# 1   Workers_True          47.65        [0.0, 96.59]     -1.0
# Underrepresented records from column : Workers
# Empty DataFrame
# Columns: [Workers, Relative freq, Confidence Interval, z_score]
# Index: []
# Confidence Interval for funding is : [0.85%, 15.82%]
#                         funding  Relative freq Confidence Interval  z_score
# 0                National funds          46.41      [26.46, 66.36]     3.01
# 1   No special funding required          19.45       [3.61, 35.29]     0.88
# 2                     Companies          10.48        [0.0, 22.73]     0.17
# 3                European Funds           8.69        [0.0, 19.96]     0.03
# 4                      Employer           4.48        [0.0, 12.76]    -0.30
# 5                Regional funds           2.90         [0.0, 9.61]    -0.43
# 6                         Other           1.79         [0.0, 7.09]    -0.52
# 7        Employers organisation           1.72         [0.0, 6.92]    -0.52
# 8                   Local funds           1.66         [0.0, 6.77]    -0.53
# 9                     Employees           1.24         [0.0, 5.67]    -0.56
# 10                  Trade union           0.97         [0.0, 4.89]    -0.58
# 11      Social partners jointly           0.21         [0.0, 2.04]    -0.64
# Overrepresented records from column : funding
#                        funding  Relative freq Confidence Interval  z_score
# 0               National funds          46.41      [26.46, 66.36]     3.01
# 1  No special funding required          19.45       [3.61, 35.29]     0.88
# Normal represented records from column : funding
#                    funding  Relative freq Confidence Interval  z_score
# 2                Companies          10.48        [0.0, 22.73]     0.17
# 3           European Funds           8.69        [0.0, 19.96]     0.03
# 4                 Employer           4.48        [0.0, 12.76]    -0.30
# 5           Regional funds           2.90         [0.0, 9.61]    -0.43
# 6                    Other           1.79         [0.0, 7.09]    -0.52
# 7   Employers organisation           1.72         [0.0, 6.92]    -0.52
# 8              Local funds           1.66         [0.0, 6.77]    -0.53
# 9                Employees           1.24         [0.0, 5.67]    -0.56
# 10             Trade union           0.97         [0.0, 4.89]    -0.58
# Underrepresented records from column : funding
#                     funding  Relative freq Confidence Interval  z_score
# 11  Social partners jointly           0.21         [0.0, 2.04]    -0.64

# %% [markdown]
# ## Class collision analysis

# %% [markdown]
# ### Define constants

# %%
CLASS_COLUMNS = ['category', 'subcategory','actors','target_groups','Businesses','Citizens','Workers', 'funding']

# %% [markdown]
# ## Function to get binary-matrix from DataFrame

# %%
def convert_to_binary_matrix(data : pd.DataFrame):
    binary_matrix = pd.DataFrame([],dtype=object)
    for index,row in data.iterrows():
        new_row = {}
        for key in row.index:
            if type(row[key]) == list:
                for column in row[key]:
                    new_row[column] = 1
            else:
                    new_row[row[key]] = 1
        binary_matrix = binary_matrix.append(new_row,ignore_index=True)
    binary_matrix = binary_matrix.fillna(0)
    return binary_matrix

# %% [markdown]
# ## Function to get dependency between columns in binary-matrix

# %%
def dependency_table( data : pd.DataFrame, dependecy_level : float = 0.9):
    result = {}
    for column in data.columns:
        tmp = data.loc[data[column]==1].copy()
        tmp = tmp.sum()
        tmp /= tmp[column]
        tmp = tmp.drop(column)
        tmp = tmp.loc[tmp.values>=dependecy_level]
        new_row = {}
        if tmp.size>0:
            for index in tmp.index:
                new_row[index] = tmp[index]
            result[column] = new_row
    return pd.DataFrame(result).fillna(0)

# %% [markdown]
# ## Categorical data collision analysis in columns

# %%
def class_collision_in_columns(data : pd.DataFrame):
    for column in data.columns:
        series = data[column]
        tmp_df = pd.DataFrame({column : series.values})
        btable = convert_to_binary_matrix(tmp_df)
        dtable = dependency_table(btable,0.7)
        if dtable.size>0:
            display(Markdown(f"Collision in column : {column}"))
            display(px.imshow(dtable))

# %%
class_collision_in_columns(df[CLASS_COLUMNS])

# %% [markdown]
# ## Analysis of categorical data collisions in DataFrame

# %%
def class_collision(data : pd.DataFrame):
    bmat = convert_to_binary_matrix(data)
    dtable = dependency_table(bmat,0.7)
    display(Markdown("Collision in dataframe"))
    display(px.imshow(dtable,aspect='auto'))

# %%
class_collision(df[CLASS_COLUMNS])

# %% [markdown]
# # Results
# ## Analysis of confidence intervals
# - This analysis gives us information about the records
# that are overrepresented and that are underrepresented.
# ## Categorical data collision analysis in columns
# - Some data in the columns collide 100%,
# which shows us that these characteristics are present only in the presence of the characteristic that collides 100%,
# so we can not give much importance to the presence of characteristics that are in collision 100% with another feature.
# ## Analysis of categorical data collisions in DataFrame
# - This analysis helps us to highlight the independent characteristics,
#  compared to the dependent ones that are in collision with a percentage higher than 70%.
# ## Observations and suggestions
# - The granularity (cardinality) of the data is relatively large,
#  with an uneven distribution, according to their proportion in the data set.
#   To create subsequent classifiers, it would be good to reduce the granularity:
#    - by reducing the dependent features (which have a collision with another feature greater than 70 ~ 90%),
#    - by grouping the features by semantic value,
#    - by segmenting the feature space and performing a max pooling or average pooling.
# - One goal to be pursued is to reduce the collisions of characteristics that will be used as classes for classifiers.
#    - To reduce the collision it is necessary to add information for these features, such as to be associated with a semantic representation of the feature.
# - Due to the relatively high granularity, the following classification methods are recommended:
#     - space segmentation and weighted average for class centers, where granularity cannot be considerably reduced
#     - KNN, SVM, Random Forest for data sets that do not have large collisions.
#     - In-depth learning methods (where the necessary collision reduction transformations will be done automatically).
